# %% [markdown]
# ### Use of Matplotlib in python

# %% [markdown]
# ## Creating plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=[1,2,3,4,5,6,7,8]
y=[44,52,49,54,57,59,58,50]
plt.xlabel("Day")
plt.ylabel("Temprature")
plt.title("Weather")
plt.plot(x,y,color='green',linewidth=5,linestyle="dotted")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=[1,2,3,4,5,6,7,8]
y=[25,21,29,24,21,20,19,18]
plt.plot(x,y)

# %% [markdown]
# # Different types of data vidualization system

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=[1,2,3,4,5,6,7,8]
y=[25,21,29,24,21,20,19,18]
plt.plot(x,y,'rD')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=[1,2,3,4,5,6,7,8]
y=[25,21,29,24,21,20,19,18]
plt.plot(x,y,color='green',marker='+',linestyle='dotted',markersize='15')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=[1,2,3,4,5,6,7,8]
y=[25,21,29,24,21,20,19,18]
plt.plot(x,y,color='blue',alpha=0.7)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x=[1,2,3,4,5,6,7,8]
y=[25,21,29,24,21,20,19,18]
plt.plot(x,y,color='blue',alpha=0.2)

# %% [markdown]
#  ## Use of Axas,label,legend and grid

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]
plt.xlabel("Days")
plt.ylabel("Temprature")
plt.title("Weather")
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avarage")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')


plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

# %% [markdown]
# # Use of Legend

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]
plt.xlabel("Days")
plt.ylabel("Temprature")
plt.title("Weather")
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avarage")
plt.legend(loc='best')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]
plt.xlabel("Days")
plt.ylabel("Temprature")
plt.title("Weather")
plt.plot(days,max_t,label="max")
plt.plot(days,min_t,label="min")
plt.plot(days,avg_t,label="avarage")
plt.legend(loc='upper right',shadow=True)
